# %% [markdown]
# # IBM Data Workbench Practice
# 3.30.2017

# %%
import pandas as pd

# %%
medals_df = pd.read_csv('medalTableOlympics.csv')

# %%
medals_df.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
medals_df.tail()
# Out:
#           Year                     City   Sport Discipline  NOC  \
# 2309      2006                    Turin  Skiing  Snowboard  USA
# 2310      2006                    Turin  Skiing  Snowboard  USA
# 2311       NaN                      NaN     NaN        NaN  NaN
# 2312    SOURCE                      IOC     NaN        NaN  NaN
# 2313  DATALINK  http://www.olympic.org/     NaN        NaN  NaN
#
#                 Event Event gender   Medal
# 2309  Snowboard Cross            M    Gold
# 2310  Snowboard Cross            W  Silver
# 2311              NaN          NaN     NaN
# 2312              NaN          NaN     NaN
# 2313              NaN          NaN     NaN

# %%
medals_df = medals_df.dropna()

# %%
medals_df.tail()
# Out:
#       Year   City   Sport Discipline  NOC            Event Event gender  \
# 2306  2006  Turin  Skiing  Snowboard  USA        Half-pipe            M
# 2307  2006  Turin  Skiing  Snowboard  USA        Half-pipe            W
# 2308  2006  Turin  Skiing  Snowboard  USA        Half-pipe            W
# 2309  2006  Turin  Skiing  Snowboard  USA  Snowboard Cross            M
# 2310  2006  Turin  Skiing  Snowboard  USA  Snowboard Cross            W
#
#        Medal
# 2306  Silver
# 2307    Gold
# 2308  Silver
# 2309    Gold
# 2310  Silver

# %%
medals_df.sort_values(by='Year', ascending=0)
# Out:
#       Year      City       Sport       Discipline  NOC  \
# 2310  2006     Turin      Skiing        Snowboard  USA
# 2137  2006     Turin      Skiing      Ski Jumping  FIN
# 2150  2006     Turin    Biathlon         Biathlon  GER
# 2149  2006     Turin   Bobsleigh         Skeleton  GBR
# 2148  2006     Turin      Skiing        Snowboard  FRA
# 2147  2006     Turin      Skiing   Freestyle Ski.  FRA
# 2146  2006     Turin      Skiing  Cross Country S  FRA
# 2145  2006     Turin      Skiing    Alpine Skiing  FRA
# 2144  2006     Turin      Skiing    Alpine Skiing  FRA
# 2143  2006     Turin    Biathlon         Biathlon  FRA
# 2142  2006     Turin    Biathlon         Biathlon  FRA
# 2141  2006     Turin    Biathlon         Biathlon  FRA
# 2140  2006     Turin    Biathlon         Biathlon  FRA
# 2139  2006     Turin      Skiing        Snowboard  FIN
# 2138  2006     Turin      Skiing      Ski Jumping  FIN
# 2136  2006     Turin      Skiing  Nordic Combined  FIN
# 2152  2006     Turin    Biathlon         Biathlon  GER
# 2135  2006     Turin      Skiing   Freestyle Ski.  FIN
# 2134  2006     Turin      Skiing  Cross Country S  FIN
# 2133  2006     Turin      Skiing    Alpine Skiing  FIN
# 2132  2006     Turin  Ice Hockey       Ice Hockey  FIN
# 2131  2006     Turin     Curling          Curling  FIN
# 2130  2006     Turin      Skiing  Cross Country S  EST
# 2129  2006     Turin      Skiing  Cross Country S  EST
# 2128  2006     Turin      Skiing  Cross Country S  EST
# 2126  2006     Turin      Skiing  Cross Country S  CZE
# 2125  2006     Turin      Skiing  Cross Country S  CZE
# 2124  2006     Turin  Ice Hockey       Ice Hockey  CZE
# 2123  2006     Turin      Skiing    Alpine Skiing  CRO
# 2122  2006     Turin      Skiing    Alpine Skiing  CRO
# ...    ...       ...         ...              ...  ...
# 5     1924  Chamonix    Biathlon         Biathlon  FIN
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN
# 2     1924  Chamonix     Skating   Figure skating  AUT
# 25    1924  Chamonix     Skating    Speed skating  NOR
# 24    1924  Chamonix     Skating    Speed skating  NOR
# 1     1924  Chamonix     Skating   Figure skating  AUT
# 26    1924  Chamonix     Skating    Speed skating  NOR
# 27    1924  Chamonix     Skating    Speed skating  NOR
# 48    1924  Chamonix      Skiing      Ski Jumping  USA
# 47    1924  Chamonix     Skating    Speed skating  USA
# 46    1924  Chamonix     Skating   Figure skating  USA
# 45    1924  Chamonix  Ice Hockey       Ice Hockey  USA
# 44    1924  Chamonix     Skating   Figure skating  SWE
# 43    1924  Chamonix     Curling          Curling  SWE
# 42    1924  Chamonix     Skating   Figure skating  SUI
# 41    1924  Chamonix   Bobsleigh        Bobsleigh  SUI
# 40    1924  Chamonix    Biathlon         Biathlon  SUI
# 39    1924  Chamonix      Skiing      Ski Jumping  NOR
# 38    1924  Chamonix      Skiing      Ski Jumping  NOR
# 37    1924  Chamonix      Skiing  Nordic Combined  NOR
# 36    1924  Chamonix      Skiing  Nordic Combined  NOR
# 35    1924  Chamonix      Skiing  Nordic Combined  NOR
# 34    1924  Chamonix      Skiing  Cross Country S  NOR
# 33    1924  Chamonix      Skiing  Cross Country S  NOR
# 32    1924  Chamonix      Skiing  Cross Country S  NOR
# 31    1924  Chamonix      Skiing  Cross Country S  NOR
# 30    1924  Chamonix      Skiing  Cross Country S  NOR
# 29    1924  Chamonix     Skating    Speed skating  NOR
# 28    1924  Chamonix     Skating    Speed skating  NOR
# 0     1924  Chamonix     Skating   Figure skating  AUT
#
#                                 Event Event gender   Medal
# 2310                  Snowboard Cross            W  Silver
# 2137                  K120 team (90m)            M  Silver
# 2150                             10km            M    Gold
# 2149                       individual            W  Silver
# 2148                  Snowboard Cross            M  Bronze
# 2147                           moguls            W  Bronze
# 2146                     Sprint 1,5km            M  Silver
# 2145                     giant slalom            M  Silver
# 2144                         downhill            M    Gold
# 2143                            7.5km            W    Gold
# 2142                    4x7.5km relay            M  Bronze
# 2141                      4x6km relay            W  Bronze
# 2140                   12.5km pursuit            M    Gold
# 2139                        Half-pipe            M  Bronze
# 2138             K90 individual (70m)            M  Silver
# 2136                             Team            M  Bronze
# 2152                     10km pursuit            W  Silver
# 2135                           moguls            M  Silver
# 2134                      Team sprint            W  Bronze
# 2133                     giant slalom            W  Silver
# 2132                       ice hockey            M  Silver
# 2131                          curling            M  Silver
# 2130  Combined 7.5 + 7.5km mass start            W    Gold
# 2129                             15km            M    Gold
# 2128                             10km            W    Gold
# 2126                             30km            W    Gold
# 2125                             15km            M  Silver
# 2124                       ice hockey            M  Bronze
# 2123                          super-G            W  Silver
# 2122                  Alpine combined            W    Gold
# ...                               ...          ...     ...
# 5                     military patrol            M  Silver
# 4                          ice hockey            M    Gold
# 2                               pairs            X    Gold
# 25                              1500m            M  Silver
# 24                              1500m            M  Bronze
# 1                          individual            W    Gold
# 26                              5000m            M  Bronze
# 27                               500m            M  Bronze
# 48               K90 individual (70m)            M  Bronze
# 47                               500m            M    Gold
# 46                         individual            W  Silver
# 45                         ice hockey            M  Silver
# 44                         individual            M    Gold
# 43                            curling            M  Silver
# 42                         individual            M  Bronze
# 41                           four-man            M    Gold
# 40                    military patrol            M    Gold
# 39               K90 individual (70m)            M  Silver
# 38               K90 individual (70m)            M    Gold
# 37                         individual            M  Silver
# 36                         individual            M    Gold
# 35                         individual            M  Bronze
# 34                               50km            M  Silver
# 33                               50km            M    Gold
# 32                               50km            M  Bronze
# 31                               18km            M  Silver
# 30                               18km            M    Gold
# 29                combined (4 events)            M  Silver
# 28                               500m            M  Silver
# 0                          individual            M  Silver
#
# [2311 rows x 8 columns]

# %%
medals_df.Year.min(), medals_df.Year.max()
# Out:
# ('1924', '2006')

# %% [markdown]
# medals_df.Year.unique

# %%
len(medals_df)
# Out:
# 2311

# %%
medals_df.Medal.unique()
# Out:
# array(['Silver', 'Gold', 'Bronze'], dtype=object)

# %%
medals_df.Medal.value_counts()
# Out:
# Gold      774
# Silver    773
# Bronze    764
# Name: Medal, dtype: int64

# %%
disciplines = medals_df.groupby(['Sport','Discipline'])

# %%
disciplines.head()
# Out:
#       Year                    City       Sport       Discipline  NOC  \
# 0     1924                Chamonix     Skating   Figure skating  AUT
# 1     1924                Chamonix     Skating   Figure skating  AUT
# 2     1924                Chamonix     Skating   Figure skating  AUT
# 3     1924                Chamonix   Bobsleigh        Bobsleigh  BEL
# 4     1924                Chamonix  Ice Hockey       Ice Hockey  CAN
# 5     1924                Chamonix    Biathlon         Biathlon  FIN
# 6     1924                Chamonix     Skating   Figure skating  FIN
# 7     1924                Chamonix     Skating    Speed skating  FIN
# 8     1924                Chamonix     Skating    Speed skating  FIN
# 9     1924                Chamonix     Skating    Speed skating  FIN
# 10    1924                Chamonix     Skating    Speed skating  FIN
# 11    1924                Chamonix     Skating    Speed skating  FIN
# 15    1924                Chamonix      Skiing  Cross Country S  FIN
# 16    1924                Chamonix    Biathlon         Biathlon  FRA
# 17    1924                Chamonix     Curling          Curling  FRA
# 18    1924                Chamonix     Skating   Figure skating  FRA
# 19    1924                Chamonix   Bobsleigh        Bobsleigh  GBR
# 20    1924                Chamonix     Curling          Curling  GBR
# 21    1924                Chamonix  Ice Hockey       Ice Hockey  GBR
# 30    1924                Chamonix      Skiing  Cross Country S  NOR
# 31    1924                Chamonix      Skiing  Cross Country S  NOR
# 32    1924                Chamonix      Skiing  Cross Country S  NOR
# 33    1924                Chamonix      Skiing  Cross Country S  NOR
# 35    1924                Chamonix      Skiing  Nordic Combined  NOR
# 36    1924                Chamonix      Skiing  Nordic Combined  NOR
# 37    1924                Chamonix      Skiing  Nordic Combined  NOR
# 38    1924                Chamonix      Skiing      Ski Jumping  NOR
# 39    1924                Chamonix      Skiing      Ski Jumping  NOR
# 40    1924                Chamonix    Biathlon         Biathlon  SUI
# 41    1924                Chamonix   Bobsleigh        Bobsleigh  SUI
# ...    ...                     ...         ...              ...  ...
# 149   1936  Garmisch-Partenkirchen      Skiing    Alpine Skiing  GER
# 150   1936  Garmisch-Partenkirchen      Skiing    Alpine Skiing  GER
# 151   1936  Garmisch-Partenkirchen      Skiing    Alpine Skiing  GER
# 152   1936  Garmisch-Partenkirchen      Skiing    Alpine Skiing  GER
# 207   1948              St. Moritz   Bobsleigh         Skeleton  GBR
# 210   1948              St. Moritz   Bobsleigh         Skeleton  ITA
# 408   1960            Squaw Valley    Biathlon         Biathlon  FIN
# 432   1960            Squaw Valley    Biathlon         Biathlon  SWE
# 472   1964               Innsbruck        Luge             Luge  AUT
# 473   1964               Innsbruck        Luge             Luge  AUT
# 474   1964               Innsbruck        Luge             Luge  AUT
# 486   1964               Innsbruck        Luge             Luge  EUA
# 487   1964               Innsbruck        Luge             Luge  EUA
# 1290  1992             Albertville     Skating   Short Track S.  CAN
# 1291  1992             Albertville     Skating   Short Track S.  CAN
# 1292  1992             Albertville     Skating   Short Track S.  CAN
# 1294  1992             Albertville     Skating   Short Track S.  CHN
# 1310  1992             Albertville     Skating   Short Track S.  EUN
# 1320  1992             Albertville      Skiing   Freestyle Ski.  EUN
# 1333  1992             Albertville      Skiing   Freestyle Ski.  FRA
# 1334  1992             Albertville      Skiing   Freestyle Ski.  FRA
# 1412  1992             Albertville      Skiing   Freestyle Ski.  NOR
# 1435  1992             Albertville      Skiing   Freestyle Ski.  USA
# 1637  1998                  Nagano      Skiing        Snowboard  AUT
# 1643  1998                  Nagano     Curling          Curling  CAN
# 1644  1998                  Nagano     Curling          Curling  CAN
# 1656  1998                  Nagano      Skiing        Snowboard  CAN
# 1688  1998                  Nagano      Skiing        Snowboard  FRA
# 1717  1998                  Nagano      Skiing        Snowboard  GER
# 1718  1998                  Nagano      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# 0               individual            M  Silver
# 1               individual            W    Gold
# 2                    pairs            X    Gold
# 3                 four-man            M  Bronze
# 4               ice hockey            M    Gold
# 5          military patrol            M  Silver
# 6                    pairs            X  Silver
# 7                   10000m            M    Gold
# 8                   10000m            M  Silver
# 9                    1500m            M    Gold
# 10                   5000m            M    Gold
# 11                   5000m            M  Silver
# 15                    18km            M  Bronze
# 16         military patrol            M  Bronze
# 17                 curling            M  Bronze
# 18                   pairs            X  Bronze
# 19                four-man            M  Silver
# 20                 curling            M    Gold
# 21              ice hockey            M  Bronze
# 30                    18km            M    Gold
# 31                    18km            M  Silver
# 32                    50km            M  Bronze
# 33                    50km            M    Gold
# 35              individual            M  Bronze
# 36              individual            M    Gold
# 37              individual            M  Silver
# 38    K90 individual (70m)            M    Gold
# 39    K90 individual (70m)            M  Silver
# 40         military patrol            M    Gold
# 41                four-man            M    Gold
# ...                    ...          ...     ...
# 149        alpine combined            M    Gold
# 150        alpine combined            M  Silver
# 151        alpine combined            W    Gold
# 152        alpine combined            W  Silver
# 207             individual            M  Bronze
# 210             individual            M    Gold
# 408                   20km            M  Silver
# 432                   20km            M    Gold
# 472                doubles            X    Gold
# 473                doubles            X  Silver
# 474                singles            W  Bronze
# 486                singles            M  Bronze
# 487                singles            M    Gold
# 1290                 1000m            M  Silver
# 1291           3000m relay            W    Gold
# 1292           5000m relay            M  Silver
# 1294                  500m            W  Silver
# 1310           3000m relay            W  Bronze
# 1320                moguls            W  Silver
# 1333                moguls            M    Gold
# 1334                moguls            M  Silver
# 1412                moguls            W  Bronze
# 1435                moguls            M  Bronze
# 1637          giant-slalom            W  Bronze
# 1643               curling            M  Silver
# 1644               curling            W    Gold
# 1656          giant-slalom            M    Gold
# 1688          giant-slalom            W    Gold
# 1717          giant-slalom            W  Silver
# 1718             Half-pipe            W    Gold
#
# [75 rows x 8 columns]

# %%
gold_df = medals_df[medals_df.Medal == 'Gold']

# %%
by_event = gold_df.groupby(['Sport','Discipline'])

# %%
by_event.head()
# Out:
#       Year            City       Sport       Discipline  NOC  \
# 1     1924        Chamonix     Skating   Figure skating  AUT
# 2     1924        Chamonix     Skating   Figure skating  AUT
# 4     1924        Chamonix  Ice Hockey       Ice Hockey  CAN
# 7     1924        Chamonix     Skating    Speed skating  FIN
# 9     1924        Chamonix     Skating    Speed skating  FIN
# 10    1924        Chamonix     Skating    Speed skating  FIN
# 14    1924        Chamonix     Skating    Speed skating  FIN
# 20    1924        Chamonix     Curling          Curling  GBR
# 30    1924        Chamonix      Skiing  Cross Country S  NOR
# 33    1924        Chamonix      Skiing  Cross Country S  NOR
# 36    1924        Chamonix      Skiing  Nordic Combined  NOR
# 38    1924        Chamonix      Skiing      Ski Jumping  NOR
# 40    1924        Chamonix    Biathlon         Biathlon  SUI
# 41    1924        Chamonix   Bobsleigh        Bobsleigh  SUI
# 44    1924        Chamonix     Skating   Figure skating  SWE
# 47    1924        Chamonix     Skating    Speed skating  USA
# 54    1928      St. Moritz  Ice Hockey       Ice Hockey  CAN
# 59    1928      St. Moritz     Skating   Figure skating  FRA
# 62    1928      St. Moritz     Skating   Figure skating  NOR
# 70    1928      St. Moritz      Skiing  Cross Country S  NOR
# 73    1928      St. Moritz      Skiing  Nordic Combined  NOR
# 75    1928      St. Moritz      Skiing      Ski Jumping  NOR
# 81    1928      St. Moritz      Skiing  Cross Country S  SWE
# 84    1928      St. Moritz   Bobsleigh        Bobsleigh  USA
# 86    1928      St. Moritz   Bobsleigh         Skeleton  USA
# 92    1932     Lake Placid  Ice Hockey       Ice Hockey  CAN
# 100   1932     Lake Placid      Skiing  Cross Country S  FIN
# 111   1932     Lake Placid      Skiing  Nordic Combined  NOR
# 114   1932     Lake Placid      Skiing      Ski Jumping  NOR
# 120   1932     Lake Placid   Bobsleigh        Bobsleigh  USA
# ...    ...             ...         ...              ...  ...
# 472   1964       Innsbruck        Luge             Luge  AUT
# 487   1964       Innsbruck        Luge             Luge  EUA
# 489   1964       Innsbruck        Luge             Luge  EUA
# 543   1964       Innsbruck    Biathlon         Biathlon  URS
# 576   1968        Grenoble        Luge             Luge  AUT
# 609   1968        Grenoble        Luge             Luge  GDR
# 627   1968        Grenoble    Biathlon         Biathlon  NOR
# 662   1968        Grenoble    Biathlon         Biathlon  URS
# 1291  1992     Albertville     Skating   Short Track S.  CAN
# 1333  1992     Albertville      Skiing   Freestyle Ski.  FRA
# 1385  1992     Albertville     Skating   Short Track S.  KOR
# 1386  1992     Albertville     Skating   Short Track S.  KOR
# 1430  1992     Albertville     Skating   Short Track S.  USA
# 1436  1992     Albertville      Skiing   Freestyle Ski.  USA
# 1461  1994     Lillehammer      Skiing   Freestyle Ski.  CAN
# 1507  1994     Lillehammer     Skating   Short Track S.  ITA
# 1559  1994     Lillehammer      Skiing   Freestyle Ski.  NOR
# 1599  1994     Lillehammer      Skiing   Freestyle Ski.  SUI
# 1644  1998          Nagano     Curling          Curling  CAN
# 1656  1998          Nagano      Skiing        Snowboard  CAN
# 1688  1998          Nagano      Skiing        Snowboard  FRA
# 1718  1998          Nagano      Skiing        Snowboard  GER
# 1802  1998          Nagano     Curling          Curling  SUI
# 1807  1998          Nagano      Skiing        Snowboard  SUI
# 1898  2002  Salt Lake City      Skiing        Snowboard  FRA
# 1902  2002  Salt Lake City     Curling          Curling  GBR
# 1972  2002  Salt Lake City     Curling          Curling  NOR
# 2028  2002  Salt Lake City   Bobsleigh         Skeleton  USA
# 2029  2002  Salt Lake City   Bobsleigh         Skeleton  USA
# 2087  2006           Turin   Bobsleigh         Skeleton  CAN
#
#                       Event Event gender Medal
# 1                individual            W  Gold
# 2                     pairs            X  Gold
# 4                ice hockey            M  Gold
# 7                    10000m            M  Gold
# 9                     1500m            M  Gold
# 10                    5000m            M  Gold
# 14      combined (4 events)            M  Gold
# 20                  curling            M  Gold
# 30                     18km            M  Gold
# 33                     50km            M  Gold
# 36               individual            M  Gold
# 38     K90 individual (70m)            M  Gold
# 40          military patrol            M  Gold
# 41                 four-man            M  Gold
# 44               individual            M  Gold
# 47                     500m            M  Gold
# 54               ice hockey            M  Gold
# 59                    pairs            X  Gold
# 62               individual            W  Gold
# 70                     18km            M  Gold
# 73               individual            M  Gold
# 75     K90 individual (70m)            M  Gold
# 81                     50km            M  Gold
# 84                 five-man            M  Gold
# 86               individual            M  Gold
# 92               ice hockey            M  Gold
# 100                    50km            M  Gold
# 111              individual            M  Gold
# 114    K90 individual (70m)            M  Gold
# 120                four-man            M  Gold
# ...                     ...          ...   ...
# 472                 doubles            X  Gold
# 487                 singles            M  Gold
# 489                 singles            W  Gold
# 543                    20km            M  Gold
# 576                 singles            M  Gold
# 609                 doubles            X  Gold
# 627                    20km            M  Gold
# 662           4x7.5km relay            M  Gold
# 1291            3000m relay            W  Gold
# 1333                 moguls            M  Gold
# 1385                  1000m            M  Gold
# 1386            5000m relay            M  Gold
# 1430                   500m            W  Gold
# 1436                 moguls            W  Gold
# 1461                 moguls            M  Gold
# 1507            5000m relay            M  Gold
# 1559                 moguls            W  Gold
# 1599                aerials            M  Gold
# 1644                curling            W  Gold
# 1656           giant-slalom            M  Gold
# 1688           giant-slalom            W  Gold
# 1718              Half-pipe            W  Gold
# 1802                curling            M  Gold
# 1807              Half-pipe            M  Gold
# 1898  Giant parallel slalom            W  Gold
# 1902                curling            W  Gold
# 1972                curling            M  Gold
# 2028             individual            M  Gold
# 2029             individual            W  Gold
# 2087             individual            M  Gold
#
# [75 rows x 8 columns]

# %%
golds_by_event = by_event.Medal.count()

# %%
golds_by_event.sort_values(ascending=False)
# Out:
# Sport       Discipline
# Skating     Speed skating      152
# Skiing      Cross Country S    134
#             Alpine Skiing      122
# Skating     Figure skating      70
# Biathlon    Biathlon            54
# Bobsleigh   Bobsleigh           39
# Skiing      Ski Jumping         38
# Luge        Luge                37
# Skating     Short Track S.      32
# Skiing      Nordic Combined     28
# Ice Hockey  Ice Hockey          23
# Skiing      Freestyle Ski.      18
#             Snowboard           14
# Curling     Curling              7
# Bobsleigh   Skeleton             6
# Name: Medal, dtype: int64

# %%
medals_by_country=medals_df.groupby(['NOC','Medal']).size()

# %%
medals_by_country.head(10)
# Out:
# NOC  Medal
# AUS  Bronze     3
#      Gold       3
# AUT  Bronze    70
#      Gold      51
#      Silver    64
# BEL  Bronze     3
#      Gold       1
#      Silver     1
# BLR  Bronze     3
#      Silver     3
# dtype: int64

# %%
type(medals_by_country)
# Out:
# pandas.core.series.Series

# %%
medals_by_country_df = medals_by_country.unstack()

# %%
medals_by_country_df.fillna(0,inplace=True)

# %%
medals_by_country_df.idxmax()
# Out:
# Medal
# Bronze    NOR
# Gold      NOR
# Silver    NOR
# dtype: object

# %%
# %matplotlib inline

# %%
medals_by_country_df.sort_values('Gold',ascending=0)
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# NOR      84.0  98.0    98.0
# USA      58.0  78.0    80.0
# URS      59.0  78.0    57.0
# GER      41.0  58.0    59.0
# AUT      70.0  51.0    64.0
# SWE      44.0  43.0    31.0
# FIN      52.0  41.0    58.0
# GDR      35.0  39.0    36.0
# CAN      43.0  38.0    38.0
# SUI      43.0  38.0    37.0
# ITA      34.0  36.0    31.0
# RUS      19.0  33.0    24.0
# NED      23.0  25.0    30.0
# FRA      34.0  25.0    24.0
# KOR       6.0  17.0     8.0
# FRG      13.0  13.0    15.0
# JPN      13.0   9.0    10.0
# EUN       8.0   9.0     6.0
# GBR      10.0   8.0     3.0
# EUA       5.0   8.0     6.0
# CRO       0.0   4.0     3.0
# CHN      13.0   4.0    16.0
# EST       1.0   4.0     1.0
# AUS       3.0   3.0     0.0
# CZE       2.0   3.0     5.0
# LIE       5.0   2.0     2.0
# TCH      15.0   2.0     8.0
# KAZ       2.0   1.0     2.0
# UZB       0.0   1.0     0.0
# BEL       3.0   1.0     1.0
# ESP       1.0   1.0     0.0
# POL       4.0   1.0     3.0
# UKR       3.0   1.0     1.0
# BUL       3.0   1.0     2.0
# BLR       3.0   0.0     3.0
# SVK       0.0   0.0     1.0
# DEN       0.0   0.0     1.0
# SLO       4.0   0.0     0.0
# LAT       1.0   0.0     0.0
# ROU       1.0   0.0     0.0
# PRK       1.0   0.0     1.0
# NZL       0.0   0.0     1.0
# HUN       4.0   0.0     2.0
# LUX       0.0   0.0     2.0
# YUG       1.0   0.0     3.0

# %%
# !pip install prettyplotlib
# Out:
# Requirement already satisfied: prettyplotlib in /home/brian/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: matplotlib>=1.2.1 in /home/brian/anaconda3/lib/python3.6/site-packages (from prettyplotlib)
# Requirement already satisfied: brewer2mpl>=1.3.1 in /home/brian/anaconda3/lib/python3.6/site-packages (from prettyplotlib)
# Requirement already satisfied: numpy>=1.7.1 in /home/brian/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.2.1->prettyplotlib)
# Requirement already satisfied: six>=1.10 in /home/brian/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.2.1->prettyplotlib)
# Requirement already satisfied: python-dateutil in /home/brian/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.2.1->prettyplotlib)
# Requirement already satisfied: pytz in /home/brian/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.2.1->prettyplotlib)
# Requirement already satisfied: cycler>=0.10 in /home/brian/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.2.1->prettyplotlib)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /home/brian/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.2.1->prettyplotlib)

# %%
import brewer2mpl
set3=brewer2mpl.get_map('Set3','qualitative',10).mpl_colors

# %%
t=medals_by_country_df.sum(axis=1)

# %%
t.sort_values(ascending=False)
awards = t[:10]

# %%
awards
# Out:
# NOC
# AUS      6.0
# AUT    185.0
# BEL      5.0
# BLR      6.0
# BUL      6.0
# CAN    119.0
# CHN     33.0
# CRO      7.0
# CZE     10.0
# DEN      1.0
# dtype: float64

# %%
countries = awards.index.values

# %%
countries
# Out:
# array(['AUS', 'AUT', 'BEL', 'BLR', 'BUL', 'CAN', 'CHN', 'CRO', 'CZE', 'DEN'], dtype=object)

# %%
total=float(t.sum())

# %%
import pylab as plt

# %%
pct = lambda x: '{p:1.1f}%'.format(p=(x*sum(awards)/100)/total*100)
plt.pie(awards, labels=countries, shadow=True, 
        autopct=pct, colors=set3, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.show()

# %%
#transpose data
import numpy as np
dates = pd.date_range('20140102',periods=4)

# %%
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=['A','B','C','D','E'])

# %%
df
# Out:
#                    A         B         C         D         E
# 2014-01-02 -0.061878 -0.937841 -0.120532 -0.700659 -0.534289
# 2014-01-03 -1.201880  2.682122 -0.692997  0.425171 -0.347173
# 2014-01-04  0.193958  1.544321 -0.962888  1.006885  0.626453
# 2014-01-05  0.213670  0.027540  2.466252 -1.435936 -0.012650

# %%
df.sort_values(by='A',ascending=0)
# Out:
#                    A         B         C         D         E
# 2014-01-05  0.213670  0.027540  2.466252 -1.435936 -0.012650
# 2014-01-04  0.193958  1.544321 -0.962888  1.006885  0.626453
# 2014-01-02 -0.061878 -0.937841 -0.120532 -0.700659 -0.534289
# 2014-01-03 -1.201880  2.682122 -0.692997  0.425171 -0.347173

# %%
df.loc['20140103','D']
# Out:
# 0.42517071288773017

# %%
df[0:2]
# Out:
#                    A         B         C         D         E
# 2014-01-02 -0.061878 -0.937841 -0.120532 -0.700659 -0.534289
# 2014-01-03 -1.201880  2.682122 -0.692997  0.425171 -0.347173

# %%
df[df.A>0]
# Out:
#                    A         B         C         D         E
# 2014-01-04  0.193958  1.544321 -0.962888  1.006885  0.626453
# 2014-01-05  0.213670  0.027540  2.466252 -1.435936 -0.012650

# %%
df[df.A==0.061316]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
df['F']=[1,2,3,4]

# %%
df
# Out:
#                    A         B         C         D         E  F
# 2014-01-02 -0.061878 -0.937841 -0.120532 -0.700659 -0.534289  1
# 2014-01-03 -1.201880  2.682122 -0.692997  0.425171 -0.347173  2
# 2014-01-04  0.193958  1.544321 -0.962888  1.006885  0.626453  3
# 2014-01-05  0.213670  0.027540  2.466252 -1.435936 -0.012650  4

# %%
df[df.F==2]
# Out:
#                   A         B         C         D         E  F
# 2014-01-03 -1.20188  2.682122 -0.692997  0.425171 -0.347173  2

# %%
df[(df.D<0) & (df.F==2)]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F]
# Index: []

# %%
df.F.isin([2])
# Out:
# 2014-01-02    False
# 2014-01-03     True
# 2014-01-04    False
# 2014-01-05    False
# Freq: D, Name: F, dtype: bool

# %%
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.492958  0.685992
# 1  bar    one  1.568955  0.213349
# 2  foo    two  1.036004 -0.159687
# 3  bar  three -0.267247 -1.439832
# 4  foo    two  0.871420  0.746844
# 5  bar    two -1.102997  1.111132
# 6  foo    one  0.837844  0.551867
# 7  foo  three  0.618587 -0.983282

# %%
dfA = df.groupby('A').groups

# %%
dfA
# Out:
# {'bar': Int64Index([1, 3, 5], dtype='int64'),
#  'foo': Int64Index([0, 2, 4, 6, 7], dtype='int64')}

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.198710 -0.115351
# foo  3.856814  0.841734

# %%
A = df.groupby(['A','B']).sum()

# %%
A
# Out:
#                   C         D
# A   B
# bar one    1.568955  0.213349
#     three -0.267247 -1.439832
#     two   -1.102997  1.111132
# foo one    1.330802  1.237859
#     three  0.618587 -0.983282
#     two    1.907425  0.587157

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.492958  0.685992
# 1  bar    one  1.568955  0.213349
# 2  foo    two  1.036004 -0.159687
# 3  bar  three -0.267247 -1.439832
# 4  foo    two  0.871420  0.746844
# 5  bar    two -1.102997  1.111132
# 6  foo    one  0.837844  0.551867
# 7  foo  three  0.618587 -0.983282

# %%
AA=df.groupby(['A', 'B']).groups.keys()

# %%
x=df.iloc[0:2]['A']

# %%
df['C'].count()
# Out:
# 8

# %%
AA
# Out:
# dict_keys([('bar', 'one'), ('bar', 'three'), ('bar', 'two'), ('foo', 'one'), ('foo', 'three'), ('foo', 'two')])

# %%
data = np.array([['','Col1','Col2'],
                ['Row1',1,2],
                ['Row2',3,4]])

# %%
data[1:,1:]
# Out:
# array([['1', '2'],
#        ['3', '4']],
#       dtype='<U4')

# %%
B=pd.DataFrame(data=data[1:,1:],
                  index=data[1:,0],
                  columns=data[0,1:])

# %%
B.iloc[1][0:]
# Out:
# Col1    3
# Col2    4
# Name: Row2, dtype: object

# %%
B.iloc[0]['Col1']
# Out:
# '1'

# %%
doubler = lambda x: x*2

# %%
B['Col2'].apply(doubler)
# Out:
# Row1    22
# Row2    44
# Name: Col2, dtype: object

# %%
doubler(10)
# Out:
# 20
